# %%
from minio import Minio
import s3fs
import os
import matplotlib.pyplot as plt
import xarray as xr
import pickle

fs = s3fs.S3FileSystem(
    client_kwargs={
        "endpoint_url": "http://192.168.1.237:9000"
    },
    key="d0d250b2541ac33f4660",
    secret="2fb32d964768bc94a3c0"
)

output_dir='/home/scratch/Abel_data/hw_processed/ctrl/'

# %%
# for r in range(1,2):
#     t_run=[]
#     for y in range(1,3):

#         # Path inside the bucket to your Zarr store
#         zarr_path = "abel-long-run/Regridded_data/run"+str(r)+"/year"+str(y)
#         ds = xr.open_zarr(fs.get_mapper(zarr_path))
#         print(ds)
#         print(ds.mean(dim='time'))

# %%
ds_master=[]
for r in range(1,2):
    ds_temp=[]
    for y in range(1,3):
        print(y)

        # Path inside the bucket to your Zarr store
        zarr_path = "abel-long-run/Regridded_data/run"+str(r)+"/year"+str(y)
        ds = xr.open_zarr(fs.get_mapper(zarr_path))
        ds_temp.append(ds.mean(dim='time'))
        
    ds_master.append(xr.concat(ds_temp, dim="ensemble").mean(dim="ensemble"))
    ds_temp=[]
    
ds_mean=xr.concat(ds_master, dim="ensemble").mean(dim="ensemble")
ds_mean
# Out:
# 1
# 2
# <xarray.Dataset> Size: 23MB
# Dimensions:                                   (lev: 50, lat: 64, lon: 128)
# Coordinates:
#   * lev                                       (lev) int64 400B 100000 ... 2000
#   * lat                                       (lat) float64 512B 87.86 ... -8...
#   * lon                                       (lon) float64 1kB 0.0 ... 357.2
# Data variables: (12/14)
#     air_pressure                              (lev, lat, lon) float64 3MB 1e+...
#     air_temperature                           (lev, lat, lon) float64 3MB 252...
#     boundary_layer_height                     (lat, lon) float32 33kB 473.8 ....
#     divergence_of_wind                        (lev, lat, lon) float64 3MB 1.7...
#     eastward_wind                             (lev, lat, lon) float64 3MB 0.1...
#     northward_wind                            (lev, lat, lon) float64 3MB -0....
#     ...                                        ...
#     surface_downwelling_longwave_flux_in_air  (lat, lon) float32 33kB 153.2 ....
#     surface_temperature                       (lat, lon) float32 33kB 251.8 ....
#     surface_upward_latent_heat_flux           (lat, lon) float32 33kB -7.051 ...
#     surface_upward_sensible_heat_flux         (lat, lon) float32 33kB -14.86 ...
#     surface_upwelling_longwave_flux_in_air    (lat, lon) float32 33kB 227.9 ....
#     vertical_wind                             (lev, lat, lon) float64 3MB nan...
